# %% [markdown]
# # Chart: Apple Quarterly Revenue

# %%
import matplotlib.pyplot as plt
import yfinance as yf

aapl = yf.Ticker("AAPL")
aapl.quarterly_financials.T[["Net Income", "Total Revenue"]].plot()
plt.title("AAPL Net Income and Total Revenue")
plt.ylim(0)
plt.show();
