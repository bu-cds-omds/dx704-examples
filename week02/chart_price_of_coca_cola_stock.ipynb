# %% [markdown]
# # Chart: Price of Coca Cola Stock

# %%
import matplotlib.pyplot as plt
import yfinance as yf

data = yf.download("KO", start="2000-01-01", end="2025-12-31", auto_adjust=True, progress=False)
data["Close"].plot()
plt.ylim(0)
plt.show();
