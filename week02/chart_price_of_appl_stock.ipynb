# %% [markdown]
# # Chart: Price of APPL Stock

# %%
import matplotlib.pyplot as plt
import yfinance as yf

data = yf.download("AAPL", start="2000-01-01", end="2025-12-31", progress=False)
data["Close"].plot()
plt.ylim(0)
plt.show();
