# %% [markdown]
# # Chart: APPL Trading Volume

# %%
import matplotlib.pyplot as plt
import yfinance as yf

data = yf.download("AAPL", start="2020-01-01", end="2025-12-31", progress=False)
data["Volume"].plot()
plt.ylim(0)
plt.show();
