# %%
import numpy as np
import pandas as pd

# %%
recipes = pd.read_csv('https://raw.githubusercontent.com/bu-cds-dx704/dx704-project-04/refs/heads/main/recipes.tsv', sep="\t")
recipes = recipes.set_index("recipe_slug")
recipes
# Out:
#                                             recipe_title  \
# recipe_slug
# falafel                                          Falafel
# spamburger                                    Spamburger
# bacon-fried-rice                        Bacon Fried Rice
# chicken-fingers                          Chicken Fingers
# apple-crisp                                  Apple Crisp
# ...                                                  ...
# bacon-mac-and-cheese                Bacon Mac And Cheese
# chicken-alfredo-lasagna          Chicken Alfredo Lasagna
# classic-beef-lasagna                Classic Beef Lasagna
# vegetarian-mushroom-lasagna  Vegetarian Mushroom Lasagna
# spinach-and-ricotta-lasagna  Spinach And Ricotta Lasagna
#
#                                                            recipe_introduction
# recipe_slug
# falafel                      Falafel is a popular Middle Eastern dish made ...
# spamburger                   Spamburger is a type of hamburger that is made...
# bacon-fried-rice             Bacon fried rice is a savory and satisfying di...
# chicken-fingers              Chicken fingers are a popular dish made from c...
# apple-crisp                  Apple crisp is a classic dessert made with bak...
# ...                                                                        ...
# bacon-mac-and-cheese         Bacon mac and cheese is a delicious and comfor...
# chicken-alfredo-lasagna      Chicken alfredo lasagna is a delicious twist o...
# classic-beef-lasagna         Classic beef lasagna is a hearty and comfortin...
# vegetarian-mushroom-lasagna  Vegetarian mushroom lasagna is a delicious and...
# spinach-and-ricotta-lasagna  Spinach and ricotta lasagna is a delicious veg...
#
# [100 rows x 2 columns]

# %%
def add_feature(feature_name):
    recipes[feature_name] = recipes["recipe_title"].str.lower().str.contains(feature_name.lower())

# %%
add_feature("apple")
add_feature("bacon")
add_feature("chicken")
add_feature("crisp")
add_feature("lasagna")
add_feature("veg")

recipes
# Out:
#                                             recipe_title  \
# recipe_slug
# falafel                                          Falafel
# spamburger                                    Spamburger
# bacon-fried-rice                        Bacon Fried Rice
# chicken-fingers                          Chicken Fingers
# apple-crisp                                  Apple Crisp
# ...                                                  ...
# bacon-mac-and-cheese                Bacon Mac And Cheese
# chicken-alfredo-lasagna          Chicken Alfredo Lasagna
# classic-beef-lasagna                Classic Beef Lasagna
# vegetarian-mushroom-lasagna  Vegetarian Mushroom Lasagna
# spinach-and-ricotta-lasagna  Spinach And Ricotta Lasagna
#
#                                                            recipe_introduction  \
# recipe_slug
# falafel                      Falafel is a popular Middle Eastern dish made ...
# spamburger                   Spamburger is a type of hamburger that is made...
# bacon-fried-rice             Bacon fried rice is a savory and satisfying di...
# chicken-fingers              Chicken fingers are a popular dish made from c...
# apple-crisp                  Apple crisp is a classic dessert made with bak...
# ...                                                                        ...
# bacon-mac-and-cheese         Bacon mac and cheese is a delicious and comfor...
# chicken-alfredo-lasagna      Chicken alfredo lasagna is a delicious twist o...
# classic-beef-lasagna         Classic beef lasagna is a hearty and comfortin...
# vegetarian-mushroom-lasagna  Vegetarian mushroom lasagna is a delicious and...
# spinach-and-ricotta-lasagna  Spinach and ricotta lasagna is a delicious veg...
#
#                              apple  bacon  chicken  crisp  lasagna    veg
# recipe_slug
# falafel                      False  False    False  False    False  False
# spamburger                   False  False    False  False    False  False
# bacon-fried-rice             False   True    False  False    False  False
# chicken-fingers              False  False     True  False    False  False
# apple-crisp                   True  False    False   True    False  False
# ...                            ...    ...      ...    ...      ...    ...
# bacon-mac-and-cheese         False   True    False  False    False  False
# chicken-alfredo-lasagna      False  False     True  False     True  False
# classic-beef-lasagna         False  False    False  False     True  False
# vegetarian-mushroom-lasagna  False  False    False  False     True   True
# spinach-and-ricotta-lasagna  False  False    False  False     True  False
#
# [100 rows x 8 columns]

# %%
ratings = pd.DataFrame({"recipe_title": recipes["recipe_title"],
                               "rating_bad": np.random.uniform(low=2, high=3, size=len(recipes))},
                              index=recipes.index)
ratings.loc[recipes['veg'], 'rating_bad'] = 1
ratings.loc[recipes['bacon'], 'rating_bad'] = 5
ratings['rating'] = ratings['rating_bad']
ratings
# Out:
#                                             recipe_title  rating_bad    rating
# recipe_slug
# falafel                                          Falafel    2.630769  2.630769
# spamburger                                    Spamburger    2.975923  2.975923
# bacon-fried-rice                        Bacon Fried Rice    5.000000  5.000000
# chicken-fingers                          Chicken Fingers    2.709550  2.709550
# apple-crisp                                  Apple Crisp    2.923251  2.923251
# ...                                                  ...         ...       ...
# bacon-mac-and-cheese                Bacon Mac And Cheese    5.000000  5.000000
# chicken-alfredo-lasagna          Chicken Alfredo Lasagna    2.087846  2.087846
# classic-beef-lasagna                Classic Beef Lasagna    2.108806  2.108806
# vegetarian-mushroom-lasagna  Vegetarian Mushroom Lasagna    1.000000  1.000000
# spinach-and-ricotta-lasagna  Spinach And Ricotta Lasagna    2.445823  2.445823
#
# [100 rows x 3 columns]

# %%
features = recipes[[c for c in recipes.columns if not c.startswith("recipe_")]]
features
# Out:
#                              apple  bacon  chicken  crisp  lasagna    veg
# recipe_slug
# falafel                      False  False    False  False    False  False
# spamburger                   False  False    False  False    False  False
# bacon-fried-rice             False   True    False  False    False  False
# chicken-fingers              False  False     True  False    False  False
# apple-crisp                   True  False    False   True    False  False
# ...                            ...    ...      ...    ...      ...    ...
# bacon-mac-and-cheese         False   True    False  False    False  False
# chicken-alfredo-lasagna      False  False     True  False     True  False
# classic-beef-lasagna         False  False    False  False     True  False
# vegetarian-mushroom-lasagna  False  False    False  False     True   True
# spinach-and-ricotta-lasagna  False  False    False  False     True  False
#
# [100 rows x 6 columns]

# %%
features.sum()
# Out:
# apple       4
# bacon      13
# chicken     5
# crisp       6
# lasagna     6
# veg         2
# dtype: int64

# %%
features.T.sum().T
# Out:
# recipe_slug
# falafel                        0
# spamburger                     0
# bacon-fried-rice               1
# chicken-fingers                1
# apple-crisp                    2
#                               ..
# bacon-mac-and-cheese           1
# chicken-alfredo-lasagna        2
# classic-beef-lasagna           1
# vegetarian-mushroom-lasagna    2
# spinach-and-ricotta-lasagna    1
# Length: 100, dtype: int64

# %%
def calculate_bounds(recipe_choices=[], alpha=1.0):
    recipe_choices = list(recipe_choices)

    D = features.loc[recipe_choices].to_numpy(dtype="float64")
    c = ratings.loc[recipe_choices, 'rating'].to_numpy(dtype="float64")

    DTDI = np.eye(D.shape[1])
    if len(recipe_choices) > 0:
        DTDI += D.T @ D
    DTDI_inv = np.linalg.inv(DTDI)

    theta_hat = DTDI_inv @ D.T @ c
    features_array = features.to_numpy()
    means = features_array @ theta_hat

    variances = []
    for z in features_array:
        z = z.reshape(-1, 1)
        variances.append((z.T @ DTDI_inv @ z).item())
    variances = np.array(variances)

    df = pd.DataFrame({"score_estimate": means,
    "score_bound": means + alpha * np.sqrt(variances)}, index=features.index)
    df["num_features"] = features.T.sum().T

    return df

calculate_bounds().sort_values("score_bound", ascending=False)
# Out:
#                                         score_estimate  score_bound  \
# recipe_slug
# cranberry-apple-crisp                              0.0     1.414214
# apple-crisp                                        0.0     1.414214
# chicken-alfredo-lasagna                            0.0     1.414214
# vegetable-lasagna                                  0.0     1.414214
# vegetarian-mushroom-lasagna                        0.0     1.414214
# ...                                                ...          ...
# cherry-pie                                         0.0     0.000000
# cold-sesame-noodles                                0.0     0.000000
# soba-noodle-salad-with-peanut-dressing             0.0     0.000000
# dan-dan-noodles                                    0.0     0.000000
# vanilla-souffle                                    0.0     0.000000
#
#                                         num_features
# recipe_slug
# cranberry-apple-crisp                              2
# apple-crisp                                        2
# chicken-alfredo-lasagna                            2
# vegetable-lasagna                                  2
# vegetarian-mushroom-lasagna                        2
# ...                                              ...
# cherry-pie                                         0
# cold-sesame-noodles                                0
# soba-noodle-salad-with-peanut-dressing             0
# dan-dan-noodles                                    0
# vanilla-souffle                                    0
#
# [100 rows x 3 columns]

# %%
calculate_bounds(["bacon-mac-and-cheese"]* 3)
# Out:
#                              score_estimate  score_bound  num_features
# recipe_slug
# falafel                                0.00     0.000000             0
# spamburger                             0.00     0.000000             0
# bacon-fried-rice                       3.75     4.250000             1
# chicken-fingers                        0.00     1.000000             1
# apple-crisp                            0.00     1.414214             2
# ...                                     ...          ...           ...
# bacon-mac-and-cheese                   3.75     4.250000             1
# chicken-alfredo-lasagna                0.00     1.414214             2
# classic-beef-lasagna                   0.00     1.000000             1
# vegetarian-mushroom-lasagna            0.00     1.414214             2
# spinach-and-ricotta-lasagna            0.00     1.000000             1
#
# [100 rows x 3 columns]

# %%
def try_picks(**kwargs):
    recipe_choices = []
    for i in range(100):
        current_bounds = calculate_bounds([r.index[0] for r in recipe_choices], **kwargs)
        best_bound = current_bounds["score_bound"].max()
        best_recipes = current_bounds[current_bounds["score_bound"] == best_bound].copy()
        best_recipes["true_rating"] = ratings.loc[best_recipes.index, "rating"]
        choice = best_recipes.sample(1)
        recipe_choices.append(choice)

    return pd.concat(recipe_choices, axis=0).reset_index()

picks = try_picks()
picks
# Out:
#                     recipe_slug  score_estimate  score_bound  num_features  \
# 0   vegetarian-mushroom-lasagna        0.000000     1.414214             2
# 1       chicken-alfredo-lasagna        0.333333     1.624328             2
# 2       chicken-alfredo-lasagna        1.429904     2.220473             2
# 3       chicken-alfredo-lasagna        1.682958     2.303132             2
# 4       chicken-alfredo-lasagna        1.795427     2.322474             2
# ..                          ...             ...          ...           ...
# 95        bacon-wrapped-chicken        4.951269     5.082905             2
# 96        bacon-wrapped-chicken        4.952099     5.082609             2
# 97        bacon-wrapped-chicken        4.952901     5.082314             2
# 98        bacon-wrapped-chicken        4.953677     5.082020             2
# 99        bacon-wrapped-chicken        4.954427     5.081726             2
#
#     true_rating
# 0      1.000000
# 1      2.087846
# 2      2.087846
# 3      2.087846
# 4      2.087846
# ..          ...
# 95     5.000000
# 96     5.000000
# 97     5.000000
# 98     5.000000
# 99     5.000000
#
# [100 rows x 5 columns]

# %%
picks.groupby("recipe_slug").count()
# Out:
#                              score_estimate  score_bound  num_features  \
# recipe_slug
# bacon-wrapped-chicken                    62           62            62
# chicken-alfredo-lasagna                  37           37            37
# vegetarian-mushroom-lasagna               1            1             1
#
#                              true_rating
# recipe_slug
# bacon-wrapped-chicken                 62
# chicken-alfredo-lasagna               37
# vegetarian-mushroom-lasagna            1

# %%
picks = try_picks(alpha=2)
picks.groupby("recipe_slug").count()
# Out:
#                              score_estimate  score_bound  num_features  \
# recipe_slug
# bacon-wrapped-chicken                    98           98            98
# chicken-alfredo-lasagna                   1            1             1
# vegetarian-mushroom-lasagna               1            1             1
#
#                              true_rating
# recipe_slug
# bacon-wrapped-chicken                 98
# chicken-alfredo-lasagna                1
# vegetarian-mushroom-lasagna            1

# %%
ratings["rating_good"] = (ratings["rating_bad"] - 1) * 0.2
ratings["rating"] = ratings["rating_good"]
ratings
# Out:
#                                             recipe_title  rating_bad  \
# recipe_slug
# falafel                                          Falafel    2.630769
# spamburger                                    Spamburger    2.975923
# bacon-fried-rice                        Bacon Fried Rice    5.000000
# chicken-fingers                          Chicken Fingers    2.709550
# apple-crisp                                  Apple Crisp    2.923251
# ...                                                  ...         ...
# bacon-mac-and-cheese                Bacon Mac And Cheese    5.000000
# chicken-alfredo-lasagna          Chicken Alfredo Lasagna    2.087846
# classic-beef-lasagna                Classic Beef Lasagna    2.108806
# vegetarian-mushroom-lasagna  Vegetarian Mushroom Lasagna    1.000000
# spinach-and-ricotta-lasagna  Spinach And Ricotta Lasagna    2.445823
#
#                                rating  rating_good
# recipe_slug
# falafel                      0.326154     0.326154
# spamburger                   0.395185     0.395185
# bacon-fried-rice             0.800000     0.800000
# chicken-fingers              0.341910     0.341910
# apple-crisp                  0.384650     0.384650
# ...                               ...          ...
# bacon-mac-and-cheese         0.800000     0.800000
# chicken-alfredo-lasagna      0.217569     0.217569
# classic-beef-lasagna         0.221761     0.221761
# vegetarian-mushroom-lasagna  0.000000     0.000000
# spinach-and-ricotta-lasagna  0.289165     0.289165
#
# [100 rows x 4 columns]

# %%
picks = try_picks(alpha=2)
picks.groupby("recipe_slug").count()
# Out:
#                                   score_estimate  score_bound  num_features  \
# recipe_slug
# apple-crisp                                    3            3             3
# apple-pie                                      1            1             1
# bacon-and-egg-breakfast-sandwich               4            4             4
# bacon-chocolate-chip-cookies                   3            3             3
# bacon-egg-muffins                              1            1             1
# bacon-fried-rice                               2            2             2
# bacon-mac-and-cheese                           4            4             4
# bacon-souffle                                  3            3             3
# bacon-wrapped-asparagus                        5            5             5
# bacon-wrapped-chicken                         47           47            47
# bacon-wrapped-dates                            6            6             6
# bacon-wrapped-scallops                         2            2             2
# bacon-wrapped-shrimp-skewers                   2            2             2
# berry-crisp                                    1            1             1
# blueberry-crisp                                1            1             1
# chicken-alfredo-lasagna                        3            3             3
# cranberry-apple-crisp                          3            3             3
# maple-bacon-donuts                             4            4             4
# maple-bacon-pancakes                           1            1             1
# peach-crisp                                    1            1             1
# vegetable-lasagna                              1            1             1
# vegetarian-mushroom-lasagna                    2            2             2
#
#                                   true_rating
# recipe_slug
# apple-crisp                                 3
# apple-pie                                   1
# bacon-and-egg-breakfast-sandwich            4
# bacon-chocolate-chip-cookies                3
# bacon-egg-muffins                           1
# bacon-fried-rice                            2
# bacon-mac-and-cheese                        4
# bacon-souffle                               3
# bacon-wrapped-asparagus                     5
# bacon-wrapped-chicken                      47
# bacon-wrapped-dates                         6
# bacon-wrapped-scallops                      2
# bacon-wrapped-shrimp-skewers                2
# berry-crisp                                 1
# blueberry-crisp                             1
# chicken-alfredo-lasagna                     3
# cranberry-apple-crisp                       3
# maple-bacon-donuts                          4
# maple-bacon-pancakes                        1
# peach-crisp                                 1
# vegetable-lasagna                           1
# vegetarian-mushroom-lasagna                 2
